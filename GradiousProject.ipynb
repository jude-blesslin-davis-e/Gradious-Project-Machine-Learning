# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score , precision_score ,  f1_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv("Bankruptcy.csv")

# %%
df.head()
# Out:
#    BankruptcyFlag  ROA_PreTax_DepAdj  ROA_AfterTax  ROA_BookDep  \
# 0               1           0.370594      0.424389     0.405750
# 1               1           0.464291      0.538214     0.516730
# 2               1           0.426071      0.499019     0.472295
# 3               1           0.399844      0.451265     0.457733
# 4               1           0.465022      0.538432     0.522298
#
#    GrossMargin_Op  GrossMargin_Realized  OpProfit_Margin  NetMargin_PreTax  \
# 0        0.601457              0.601457         0.998969          0.796887
# 1        0.610235              0.610235         0.998946          0.797380
# 2        0.601450              0.601364         0.998857          0.796403
# 3        0.583541              0.583541         0.998700          0.796967
# 4        0.598783              0.598783         0.998973          0.797366
#
#    NetMargin_AfterTax  NonOp_RevRatio  ...  NetIncome_to_Assets  \
# 0            0.808809        0.302646  ...             0.716845
# 1            0.809301        0.303556  ...             0.795297
# 2            0.808388        0.302035  ...             0.774670
# 3            0.808966        0.303350  ...             0.739555
# 4            0.809304        0.303475  ...             0.795016
#
#    Assets_to_GNP  NoCredit_Period  GrossProfit_to_Sales  NetIncome_to_Equity  \
# 0       0.009219         0.622879              0.601453             0.827890
# 1       0.008323         0.623652              0.610237             0.839969
# 2       0.040003         0.623841              0.601449             0.836774
# 3       0.003252         0.622929              0.583538             0.834697
# 4       0.003878         0.623521              0.598782             0.839973
#
#    Liabilities_to_Equity       DFL  InterestCoverage  NetIncome_PositiveFlag  \
# 0               0.290202  0.026601          0.564050                       1
# 1               0.283846  0.264577          0.570175                       1
# 2               0.290189  0.026555          0.563706                       1
# 3               0.281721  0.026697          0.564663                       1
# 4               0.278514  0.024752          0.575617                       1
#
#    Equity_to_Liabilities
# 0               0.016469
# 1               0.020794
# 2               0.016474
# 3               0.023982
# 4               0.035490
#
# [5 rows x 96 columns]

# %%
x = df.drop('BankruptcyFlag' , axis  = 1)

# %%
x.shape
# Out:
# (6819, 95)

# %%
y = df['BankruptcyFlag']

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6814    0
# 6815    0
# 6816    0
# 6817    0
# 6818    0
# Name: BankruptcyFlag, Length: 6819, dtype: int64

# %%
df = df.dropna(thresh=len(df)*0.4, axis=1)
df = df.fillna(df.median())
x = df.drop("BankruptcyFlag", axis=1)
y = df["BankruptcyFlag"]

# %%
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
x
# Out:
# array([[-2.21790935, -2.04579778, -2.40036101, ..., -0.09897788,
#          0.        , -0.62206729],
#        [-0.6738282 , -0.31106786, -0.59844969, ...,  0.36455867,
#          0.        , -0.53557337],
#        [-1.30367191, -0.90841978, -1.3199096 , ..., -0.12501504,
#          0.        , -0.62195985],
#        ...,
#        [-0.53484482, -0.37919423, -0.53499599, ..., -0.0151013 ,
#          0.        ,  1.00120639],
#        [ 0.01787517,  0.01959425,  0.00740278, ..., -0.00427045,
#          0.        , -0.07136385],
#        [-0.19983866,  0.1749556 , -0.06561244, ..., -0.01445437,
#          0.        ,  3.72572885]], shape=(6819, 95))

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.3)

# %%
x_train
# Out:
# array([[-0.57742355, -0.49883078, -0.55411902, ..., -0.42226854,
#          0.        , -0.35784219],
#        [ 0.69511785,  0.96671691,  0.86967776, ..., -0.00647974,
#          0.        , -0.18938939],
#        [-0.59750784, -0.30192896, -0.52369601, ...,  0.05726822,
#          0.        , -0.57065534],
#        ...,
#        [-0.18698471, -0.26205012, -0.15861992, ...,  0.12641355,
#          0.        ,  0.14685749],
#        [ 1.64711377,  1.30651794,  1.24605384, ..., -0.01406303,
#          0.        , -0.36709987],
#        [ 0.02831902,  0.10516761,  0.13257173, ...,  0.07559653,
#          0.        , -0.56654973]], shape=(4773, 95))

# %% [markdown]
# Logestic Regression

# %%
log = LogisticRegression(max_iter=1000)
log.fit(x_train , y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
log.score(x_test , y_test)
# Out:
# 0.9657869012707723

# %%
y_pred = log.predict(x_test)

# %%
confusion_matrix(y_test , y_pred)
# Out:
# array([[1960,   22],
#        [  48,   16]])

# %%
accuracy_score(y_pred , y_test)
# Out:
# 0.9657869012707723

# %%
f1_score(y_pred , y_test)
# Out:
# 0.3137254901960784

# %%
precision_score(y_pred , y_test)
# Out:
# 0.25

# %% [markdown]
# Linear Regression

# %%
lr = LinearRegression()
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test , y_test)
# Out:
# -0.8873607575847722

# %%
y_pred = lr.predict(x_test)
# Out:
# array([ 0.07329925, -0.00306651,  0.06476156, ..., -0.04655021,
#        -0.01158586,  0.28176391], shape=(2046,))

# %%
mean_squared_error(y_pred , y_test)
# Out:
# 0.03421309872922776

# %% [markdown]
# K - MeansClustering

# %%
kmm = KMeans(n_clusters=3)
kmm.fit(x)
# Out:
# KMeans(n_clusters=3)

# %%
kmm.score(x_test , y_test)
# Out:
# -166106.08560276666

# %%
y_pred = kmm.predict(x_test)

# %%
silhouette_score(x , kmm.labels_)
# Out:
# 0.11627765935410124
